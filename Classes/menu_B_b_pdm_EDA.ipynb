# %% [markdown]
# <font size = 6 color = green><b> Predicitive Maintenance / 智能性维护实例 </b></font>
# # Menu B-b: EDA / 探索性数据分析

# %% [markdown]
# # Libraries / 工具库

# %%
import os
import re
import numpy as np 
from pathlib import Path 
import zipfile
import pandas as pd
import warnings

import matplotlib.pyplot as plt
import seaborn as sns 

from copy import deepcopy 

warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# # Use Our Own Tool Box / 运用我们自己的工具库

# %%
current_path = os.getcwd()

# %%
import sys 
sys.path.append(current_path)

# %% [markdown]
# # Load Data

# %%
from menu_A_a_data_utility import DataUtility

# %% [markdown]
# ## Use build-in-help utility

# %%
uti = DataUtility()

# %%
df_train, df_test, df_result = uti.prepare_dfs()

# %% [markdown]
# # Take a look

# %%
cycle=30
df_train['label'] = df_train['remaining_cycle'].apply(lambda x: 1 if x <= cycle else 0)
df_test['label'] = df_test['remaining_cycle'].apply(lambda x: 1 if x <= cycle else 0)
# Out:
#         id  cycle      op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0        1      1  -0.0007 -0.0004  100.0   518.67   641.82  1589.70  1400.60
# 1        1      2   0.0019 -0.0003  100.0   518.67   642.15  1591.82  1403.14
# 2        1      3  -0.0043  0.0003  100.0   518.67   642.35  1587.99  1404.20
# 3        1      4   0.0007  0.0000  100.0   518.67   642.35  1582.79  1401.87
# 4        1      5  -0.0019 -0.0002  100.0   518.67   642.37  1582.85  1406.22
# ...    ...    ...      ...     ...    ...      ...      ...      ...      ...
# 61244  249    251   9.9998  0.2500  100.0   489.05   605.33  1516.36  1315.28
# 61245  249    252   0.0028  0.0015  100.0   518.67   643.42  1598.92  1426.77
# 61246  249    253   0.0029  0.0000  100.0   518.67   643.68  1607.72  1430.56
# 61247  249    254  35.0046  0.8400  100.0   449.44   555.77  1381.29  1148.18
# 61248  249    255  42.0030  0.8400  100.0   445.00   549.85  1369.75  1147.45
#
# ...

# %% [markdown]
# ## Map df_train's rul

# %%
df_train["rul"] = df_train.groupby(["Flag","id"])["cycle"].transform("max")-df_train["cycle"]
df_train.head(1)
# Out:
#    id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0   1      1 -0.0007 -0.0004  100.0   518.67   641.82   1589.7   1400.6
#
#    sensor5  ...  sensor14  sensor15  sensor16  sensor17  sensor18  sensor19  \
# 0    14.62  ...   8138.62    8.4195      0.03       392      2388     100.0
#
#    sensor20  sensor21   Flag  rul
# 0     39.06    23.419  FD001  191
#
# [1 rows x 28 columns]

# %%
 df_train[(df_train["Flag"] == "FD001") & (df_train["id"] ==1)]
# Out:
#      id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0     1      1 -0.0007 -0.0004  100.0   518.67   641.82  1589.70  1400.60
# 1     1      2  0.0019 -0.0003  100.0   518.67   642.15  1591.82  1403.14
# 2     1      3 -0.0043  0.0003  100.0   518.67   642.35  1587.99  1404.20
# 3     1      4  0.0007  0.0000  100.0   518.67   642.35  1582.79  1401.87
# 4     1      5 -0.0019 -0.0002  100.0   518.67   642.37  1582.85  1406.22
# ..   ..    ...     ...     ...    ...      ...      ...      ...      ...
# 187   1    188 -0.0067  0.0003  100.0   518.67   643.75  1602.38  1422.78
# 188   1    189 -0.0006  0.0002  100.0   518.67   644.18  1596.17  1428.01
# 189   1    190 -0.0027  0.0001  100.0   518.67   643.64  1599.22  1425.95
# 190   1    191 -0.0000 -0.0004  100.0   518.67   643.34  1602.36  1425.77
# 191   1    192  0.0009 -0.0000  100.0   518.67   643.54  1601.41  1427.20
#
#      sensor5  ...  sensor14  sensor15  sensor16  sensor17  sensor18  sensor19  \
# ...

# %% [markdown]
# ## Plot engine cycles

# %%
plt.style.use('seaborn')
plt.figure(figsize=(15,20))
ax=d1.groupby('id')['cycle'].max().plot(kind='barh',width=0.8, stacked=True,align='center',rot=0)
plt.title('Engines LifeTime',fontweight='bold',size=15)
plt.xlabel('Cycles',fontweight='bold',size=12)
plt.xticks(size=12)
plt.ylabel('Engine ID',fontweight='bold',size=12)
plt.yticks(size=12)

for container in ax.containers:
    ax.bar_label(container, fontsize=12, color="red", fmt='%g')
    
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
